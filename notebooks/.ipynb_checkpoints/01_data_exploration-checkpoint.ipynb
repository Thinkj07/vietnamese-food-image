# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# Tạo tensor ngẫu nhiên đại diện cho ảnh 1 kênh 4x4
x = torch.rand(3, 3)
print("Tensor x:\n", x)
print(f"Shape: {x.shape}, Dtype: {x.dtype}, Device: {x.device}")
# Out:
# Tensor x:
#  tensor([[0.7022, 0.7858, 0.9246],
#         [0.9258, 0.7892, 0.5504],
#         [0.0500, 0.1191, 0.8587]])
# Shape: torch.Size([3, 3]), Dtype: torch.float32, Device: cpu
